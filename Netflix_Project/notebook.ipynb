# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions:
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load CSV file and Store as netflix_df
netflix_df = pd.read_csv('netflix_data.csv')

# %%
# Filter the DataFrame to extract the type movie only
netflix_subset = netflix_df[netflix_df['type'] == 'Movie']
print(netflix_subset)
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...

# %%
# Investigate Netflix Data to det which factors are relevant and should be remained
# Then Filter the DataFrame
netflix_movies = netflix_subset[['title', 'country', 'genre', 'release_year', 'duration']]

# Filter the DataFrame by cond: shorter than 60 minutes
short_movies = netflix_movies[netflix_movies['duration'] <= 60]
short_movies.to_csv('netlix_short_movies.csv', index=True)

# %%
# List contains colors for each type of Movie
colors = []

for genre in netflix_movies['genre']:
    if genre == 'Children':
        colors.append('Blue')
    elif genre == 'Documentaries':
        colors.append('Green')
    elif genre == 'Stand-Up':
        colors.append('Red')
    else:
        colors.append('Pink')

# %%
# Create a figure w/ subplots(like axises, grid, colors), by default one subplot
# ax is a subplot object of axes, when we want to add to the main figure
# ax.scatter is object-oriented approach is better since we can explicitly know which subplot(object)one we are plotting on
# plt.scatter is simpler and part of the state-based (pyplot) interface.

fig, ax = plt.subplots()
ax.scatter(netflix_movies['release_year'], netflix_movies['duration'], c=colors)

ax.set_xlabel('Release year')
ax.set_ylabel('Duration (min)')
ax.set_title('Movie Duration by Year of Release')
# Out:
# Text(0.5, 1.0, 'Movie Duration by Year of Release')

# %% [markdown]
# Based on the scatter plot, which shows movie duration by year of release, the
# data points do not indicate a clear, consistent trend that movies are getting
# shorter over time.
#
# While there seems to be a cluster of shorter movies in more recent years, there
# are also many movies with longer durations interspersed throughout. Additionally,
# there is a significant spread in the durations at all points along the timeline,
# which indicates variability in movie lengths rather than a definitive decreasing trend.
